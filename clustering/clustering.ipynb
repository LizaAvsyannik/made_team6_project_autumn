# %% [markdown]
# ### Clustering
#  In order to perform clustering we've decided to use SOTA approach BERTopic.
#  Link to paper: https://arxiv.org/pdf/2203.05794.pdf \
#  We use pretrained sentence transformer https://www.sbert.net/docs/pretrained_models.html#sentence-embedding-models to generate embeddings and set minimum topic size to 50 papers.

# %%
from bertopic import BERTopic

topic_model = BERTopic(verbose=True, embedding_model="paraphrase-MiniLM-L12-v2", min_topic_size=50)

# %%
from plotly.offline import init_notebook_mode
init_notebook_mode(connected=True)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.14.0.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %% [markdown]
# #### Data Processing

# %%
import pandas as pd
data = pd.read_csv('../datasets/004_of_V13.csv')

# %%
data.drop(data[data['lang'] == 'zh'].index, inplace=True)
data = data.dropna(subset=['abstract', 'lang', 'fos', 'keywords'])
# to get rid of papers with no abstracts
data.drop(data[data['abstract'].map(len) <= 55].index, inplace=True)
data = data.dropna(subset=['lang'])
# to get rid of german language, that is somehow not in 'lang' column
data.drop(data[data['abstract'].map(lambda x: ' der ' in x)].index, inplace=True)
data.drop(data[data['keywords'].map(lambda x: x == '[]')].index, inplace=True)

# %%
data.reset_index(inplace=True)
data.to_csv('data/004_of_V13_filtered.csv')

# %%
abstracts = data['abstract'].to_list()
len(abstracts)
# Out:
# 109042

# %% [markdown]
# #### Perform Clustering

# %%
topics, _ = topic_model.fit_transform(abstracts); len(topic_model.get_topic_info())
# Out:
# Batches:   0%|          | 0/3408 [00:00<?, ?it/s]
# 2022-10-18 15:20:24,322 - BERTopic - Transformed documents to Embeddings
# 2022-10-18 15:21:09,173 - BERTopic - Reduced dimensionality
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# 2022-10-18 15:21:12,951 - BERTopic - Clustered reduced embeddings
# 180

# %% [markdown]
# ##### We got 177 topic, let's take a look at the most frequent ones and their most representative words.

# %%
topic_model.visualize_barchart(top_n_topics=9, height=700)
# Out:
# <div>                            <div id="8a785ec5-abf5-42bf-bf27-2c09e2ba6be3" class="plotly-graph-div" style="height:2100px; width:1000px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("8a785ec5-abf5-42bf-bf27-2c09e2ba6be3")) {                    Plotly.newPlot(                        "8a785ec5-abf5-42bf-bf27-2c09e2ba6be3",                        [{"marker":{"color":"#D55E00"},"orientation":"h","x":[0.009831973266184475,0.010675720979980848,0.013753549311676348,0.015221760811928447,0.0165521170213371],"y":["method  ","convergence  ","equation  ","numerical  ","equations  "],"type":"bar","xaxis":"x","yaxis":"y"},{"marker":{"color":"#0072B2"},"orientation":"h","x":[0.011063895355609673,0.011373395633903315,0.01570678338009075,0.015723663499040134,0.021562115368287782],"y":["systems  ","nonlinear  ","controller  ","stability  ","control  "],"type":"bar","xaxis":"x2","yaxis":"y2"},{"marker":{"color":"#CC79A7"},"orientation":"h","x":[0.012409216892989183,0.012528203747710819,0.013819572368186704,0.014918237261854084,0.022931544024558135],"y":["relay  ","fading  ","interference  ","mimo  ","channel  "],"type":"bar","xaxis":"x3","yaxis":"y3"},{"marker":{"color":"#E69F00"},"orientation":"h","x":[0.00896438985561688,0.010465397348608154,0.010967639942364119,0.020391892151026467,0.03468812114944656],"y":["robotic  ","motion  ","control  ","robots  ","robot  "],"type":"bar","xaxis":"x4","yaxis":"y4"},{"marker":{"color":"#56B4E9"},"orientation":"h","x":[0.009337002513079182,0.01196576805227382,0.013706086094032437,0.017645491601564676,0.020457120049552555],"y":["genome  ","proteins  ","genes  ","gene  ","protein  "],"type":"bar","xaxis":"x5","yaxis":"y5"},{"marker":{"color":"#009E73"},"orientation":"h","x":[0.013977468727208894,0.019958518671883467,0.024934120376156325,0.034660489228370714,0.039960223425184294],"y":["edge  ","vertex  ","vertices  ","graphs  ","graph  "],"type":"bar","xaxis":"x6","yaxis":"y6"},{"marker":{"color":"#F0E442"},"orientation":"h","x":[0.007117922929235987,0.007594256091575878,0.008261183492146915,0.008866275122108611,0.06288701764182283],"y":["membership  ","decision  ","sets  ","rough  ","fuzzy  "],"type":"bar","xaxis":"x7","yaxis":"y7"},{"marker":{"color":"#D55E00"},"orientation":"h","x":[0.007935502143567238,0.008441488432852116,0.008825859363682603,0.009542122584568793,0.011309275276083506],"y":["functions  ","if  ","we  ","polynomial  ","polynomials  "],"type":"bar","xaxis":"x8","yaxis":"y8"},{"marker":{"color":"#0072B2"},"orientation":"h","x":[0.01244826928138451,0.013073016111268633,0.013498909931247902,0.025845437643024657,0.03204954291583754],"y":["student  ","education  ","teaching  ","learning  ","students  "],"type":"bar","xaxis":"x9","yaxis":"y9"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#e ...

# %%
topic_model.visualize_topics(top_n_topics=50)
# Out:
# <div>                            <div id="a9ffd803-041f-41fa-82c0-1946a018b037" class="plotly-graph-div" style="height:650px; width:650px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a9ffd803-041f-41fa-82c0-1946a018b037")) {                    Plotly.newPlot(                        "a9ffd803-041f-41fa-82c0-1946a018b037",                        [{"customdata":[[0,"equations | numerical | equation | convergence | method",2249],[1,"control | stability | controller | nonlinear | systems",2202],[2,"channel | mimo | interference | fading | relay",2134],[3,"robot | robots | control | motion | robotic",2044],[4,"protein | gene | genes | proteins | genome",1872],[5,"graph | graphs | vertices | vertex | edge",1790],[6,"fuzzy | rough | sets | decision | membership",1723],[7,"polynomials | polynomial | we | if | functions",1704],[8,"students | learning | teaching | education | student",1599],[9,"logic | semantics | calculus | proof | theory",1390],[10,"memory | cache | parallel | processor | performance",1348],[11,"speech | speaker | recognition | music | audio",1312],[12,"soil | sar | land | radar | surface",1248],[13,"key | security | scheme | secure | encryption",1211],[14,"video | coding | compression | 264 | rate",957],[15,"bayesian | estimator | regression | distribution | likelihood",849],[16,"sensor | energy | nodes | wireless | network",795],[17,"codes | decoding | code | ldpc | decoder",747],[18,"translation | word | english | corpus | language",716],[19,"segmentation | images | ct | breast | image",701],[20,"cloud | computing | virtual | vm | service",657],[21,"cmos | amplifier | adc | circuit | db",626],[22,"health | care | patient | medical | clinical",623],[23,"scheduling | jobs | job | problem | schedule",601],[24,"business | knowledge | innovation | management | organizational",600],[25,"face | facial | recognition | faces | images",592],[26,"ontology | ontologies | semantic | web | knowledge",526],[27,"clustering | clusters | cluster | data | nearest",519],[28,"agent | agents | negotiation | multi | multiagent",440],[29,"spectrum | cognitive | radio | secondary | primary",426],[30,"social | media | facebook | online | sns",413],[31,"localization | indoor | positioning | location | sensor",397],[32,"virtual | reality | vr | ar | augmented",396],[33,"energy | power | electricity | grid | charging",390],[34,"hoc | routing | ad | nodes | manet",379],[35,"image | denoising | images | resolution | reconstruction",373],[36,"stereo | 3d | images | rendering | image",367],[37,"financial | stock | market | portfolio | risk",315],[38,"genetic | ga | evolutionary | population | optimization",307],[39,"neurons | synaptic | spike | neuron | firing",302],[40,"converter | voltage | dc | power | converters",300],[41,"software | development | project | requirements | process",298],[42,"image | retrieval | images | content | query",296],[43,"web | services | service | composition | discovery",283],[44,"test | fault | faults | scan | circuits",273],[45,"retrieval | search | web | documents | query",270],[46,"citation | journals | citations | journal | papers",268],[47,"neural | training | network | networks | learning",266],[48,"recommendation | recommender | items | user | users",257],[49,"machining | cutting | crack | stress | surface",256]],"hovertemplate":"<b>Topic %{customdata[0]}</b><br>Words: %{customdata[1]}<br>Size: %{customdata[2]}","legendgroup":"","marker":{"color":"#B0BEC5","size":[2249,2202,2134,2044,1872,1790,1723,1704,1599,1390,1348,1312,1248,1211,957,849,795,747,716,701,657,626,623,601,600,592,526,519,440,426,413,397,396,390,379,373,367,315,307,302,300,298,296,283,273,270,268,266,257,256],"sizemode":"area","sizeref":1.405625,"symbol":"circle","line":{"color":"DarkSlateGrey","width":2}},"mode":"markers","name":"","orientation":"v","showlegend": ...

# %%
topic_model.visualize_hierarchy(top_n_topics=50, width=800)
# Out:
# <div>                            <div id="4e3e14f6-d15a-4877-a28e-f4c02e32081f" class="plotly-graph-div" style="height:950px; width:800px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("4e3e14f6-d15a-4877-a28e-f4c02e32081f")) {                    Plotly.newPlot(                        "4e3e14f6-d15a-4877-a28e-f4c02e32081f",                        [{"hoverinfo":"text","marker":{"color":"rgb(61,153,112)"},"mode":"lines","x":[0.0,0.7405946507126441,0.7405946507126441,0.0],"xaxis":"x","y":[-25.0,-25.0,-35.0,-35.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(61,153,112)"},"mode":"lines","x":[0.0,0.8307463672660541,0.8307463672660541,0.7405946507126441],"xaxis":"x","y":[-15.0,-15.0,-30.0,-30.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(61,153,112)"},"mode":"lines","x":[0.8307463672660541,0.9958648196630321,0.9958648196630321,0.0],"xaxis":"x","y":[-22.5,-22.5,-45.0,-45.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(0,116,217)"},"mode":"lines","x":[0.0,1.1330855637597963,1.1330855637597963,0.9958648196630321],"xaxis":"x","y":[-5.0,-5.0,-33.75,-33.75],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(255,65,54)"},"mode":"lines","x":[0.0,0.88272814684692,0.88272814684692,0.0],"xaxis":"x","y":[-55.0,-55.0,-65.0,-65.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(35,205,205)"},"mode":"lines","x":[0.0,0.7900649231004161,0.7900649231004161,0.0],"xaxis":"x","y":[-75.0,-75.0,-85.0,-85.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(0,116,217)"},"mode":"lines","x":[0.88272814684692,1.1175669418206446,1.1175669418206446,0.7900649231004161],"xaxis":"x","y":[-60.0,-60.0,-80.0,-80.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(0,116,217)"},"mode":"lines","x":[1.1330855637597963,1.4725296734375874,1.4725296734375874,1.1175669418206446],"xaxis":"x","y":[-19.375,-19.375,-70.0,-70.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(133,20,75)"},"mode":"lines","x":[0.0,0.7704352660933669,0.7704352660933669,0.0],"xaxis":"x","y":[-95.0,-95.0,-105.0,-105.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(255,220,0)"},"mode":"lines","x":[0.0,0.6689944699492733,0.6689944699492733,0.0],"xaxis":"x","y":[-125.0,-125.0,-135.0,-135.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(255,220,0)"},"mode":"lines","x":[0.0,0.8759194976468647,0.8759194976468647,0.6689944699492733],"xaxis":"x","y":[-115.0,-115.0,-130.0,-130.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(40,35,35)"},"mode":"lines","x":[0.0,0.9849109365246069,0.9849109365246069,0.0],"xaxis":"x","y":[-145.0,-145.0,-155.0,-155.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(0,116,217)"},"mode":"lines","x":[0.8759194976468647,1.053694702783011,1.053694702783011,0.9849109365246069],"xaxis":"x","y":[-122.5,-122.5,-150.0,-150.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(0,116,217)"},"mode":"lines","x":[0.7704352660933669,1.135981882167083,1.135981882167083,1.053694702783011],"xaxis":"x","y":[-100.0,-100.0,-136.25,-136.25],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(61,153,112)"},"mode":"lines","x":[0.0,0.8578756102589399,0.8578756102589399,0.0],"xaxis":"x","y":[-165.0,-165.0,-175.0,-175.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(255,65,54)"},"mode":"lines","x":[0.0,0.9273166862173906,0.9273166862173906,0.0],"xaxis":"x","y":[-195.0,-195.0,-205.0,-205.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(255,65,54)"},"mode":"lines","x":[0.0,0.9557384017160987,0.9557384017160987,0.9273166862173906]," ...

# %%
topic_model.visualize_heatmap(n_clusters=20, top_n_topics=100)
# Out:
# <div>                            <div id="1bfed82b-099c-4c36-b7b6-ed066efe78ad" class="plotly-graph-div" style="height:800px; width:800px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("1bfed82b-099c-4c36-b7b6-ed066efe78ad")) {                    Plotly.newPlot(                        "1bfed82b-099c-4c36-b7b6-ed066efe78ad",                        [{"coloraxis":"coloraxis","name":"0","x":["0_equations_numerical_equat...","17_codes_decoding_code","44_test_fault_faults","64_testing_test_cases","97_multiplication_arithmeti...","1_control_stability_control...","7_polynomials_polynomial_we","9_logic_semantics_calculus","74_filter_filters_fir","77_simulation_manufacturing...","81_pso_swarm_particle","89_verification_checking_mo...","91_maintenance_failure_reli...","2_channel_mimo_interference","16_sensor_energy_nodes","30_social_media_facebook","34_hoc_routing_ad","60_p2p_peer_peers","61_qos_service_network","76_social_community_networks","80_video_streaming_bandwidth","88_mac_protocol_protocols","3_robot_robots_control","49_machining_cutting_crack","65_gesture_gestures_hand","93_surface_surfaces_mesh","4_protein_gene_genes","37_financial_stock_market","54_watermarking_watermark_e...","68_quantum_entanglement_qubit","5_graph_graphs_vertices","6_fuzzy_rough_sets","12_soil_sar_land","15_bayesian_estimator_regre...","46_citation_journals_citati...","86_inc_wiley_calculations","95_replication_file_replica","99_classifiers_ensemble_cla...","8_students_learning_teaching","18_translation_word_english","26_ontology_ontologies_sema...","10_memory_cache_parallel","20_cloud_computing_virtual","23_scheduling_jobs_job","57_grid_resources_computing","59_svm_vector_support","63_queue_queueing_service","70_inventory_supply_retailer","79_petri_nets_net","11_speech_speaker_recognition","29_spectrum_cognitive_radio","47_neural_training_network","85_cortex_brain_prefrontal","96_brain_matter_mri","13_key_security_scheme","28_agent_agents_negotiation","56_intrusion_detection_malw...","14_video_coding_compression","31_localization_indoor_posi...","32_virtual_reality_vr","35_image_denoising_images","36_stereo_3d_images","42_image_retrieval_images","45_retrieval_search_web","51_tracking_object_target","19_segmentation_images_ct","25_face_facial_recognition","53_emotion_emotional_emotions","58_video_videos_content","72_visualization_visual_vis...","94_hiding_secret_embedding","21_cmos_amplifier_adc","62_cmos_delay_sram","22_health_care_patient","69_ecg_cardiac_heart","24_business_knowledge_innov...","38_genetic_ga_evolutionary","41_software_development_pro...","43_web_services_service","48_recommendation_recommend...","52_mining_frequent_patterns","71_middleware_mobile_distri...","83_reuse_software_components","84_uml_diagrams_object","87_soa_service_services","27_clustering_clusters_clus...","66_database_data_relational","67_xml_rdf_schema","33_energy_power_electricity","40_converter_voltage_dc","82_gpu_gpus_cuda","90_torque_motor_rotor","39_neurons_synaptic_spike","98_eeg_brain_signals","50_games_game_equilibrium","73_game_games_learning","55_tcp_congestion_packet","75_traffic_travel_flow","78_vehicular_vehicles_vanets","92_road_vehicle_vehicles"],"y":["0_equations_numerical_equat...","17_codes_decoding_code","44_test_fault_faults","64_testing_test_cases","97_multiplication_arithmeti...","1_control_stability_control...","7_polynomials_polynomial_we","9_logic_semantics_calculus","74_filter_filters_fir","77_simulation_manufacturing...","81_pso_swarm_particle","89_verification_checking_mo...","91_maintenance_failure_reli...","2_channel_mimo_interference","16_sensor_energy_nodes","30_social_media_facebook","34_hoc_routing_ad","60_p2p_peer_peers","61_qos_service_network","76_social_community_networks","80_video_streaming_bandwidth","88_mac_protocol_protocols","3_robot_robots_control" ...

# %% [markdown]
# #### Save the model and clustering results

# %%
topic_model.save('models/topic_modelling')

# %%
topics_for_each_doc = [topic_model.topic_labels_[i] for i in topic_model.topics_]
data['topic'] = topics_for_each_doc
data.head()
# Out:
#    index                       _id  \
# 0    174  53e99792b7602d9701f58152
# 1    188  53e99792b7602d9701f5b3e5
# 2    189  53e99796b7602d9701f5b9d1
# 3    190  53e99796b7602d9701f5c1a2
# 4    248  53e9979bb7602d9701f650bf
#
#                                                title  \
# 0                                           Preface.
# 1  A Method of Multiple-Marker Register and Appli...
# 2  Optimal weighting of posteriors for audio-visu...
# 3  The clinical bioinformatics ontology: a curate...
# 4                                   Digital evidence
#
#                                              authors  \
# 0  [{'name': 'Takagi Mutsumi', 'org': 'Hokkaido U...
# 1  [{'_id': '5603dcf245cedb3396276ecc', 'name': '...
# 2  [{'_id': '560c28fb45cedb33974b3f3e', 'name': '...
# 3  [{'_id': '56017d9745cedb3395e63f00', 'name': '...
# 4  [{'_id': '53f438d3dabfaedce554609c', 'name': '...
#
#                                                venue  year  \
# 0  {'_id': '53a7325720f7420be8d8fa9b', 'raw': 'An...  2005
# 1  {'sid': 'FRONTIERS IN COMPUTER EDUCATION', 'is...  2011
# 2  {'_id': '555037547cea80f9541805e0', 'raw': 'IC...  2001
# 3  {'_id': '53a7254520f7420be8b4a58f', 'name_d': ...  2005
# 4  {'_id': '555036f57cea80f954169e28', 'type': 0,...  2002
#
#                                             keywords  n_citation page_start  \
# 0  ['remote sensing', 'airborne electromagnetics'...         1.0         S1
# 1  ['Augmented Reality', 'Virtual Education', 'Co...         0.0        431
# 2  ['conditional independence', 'audio signal pro...        25.0        161
# 3  ['controlled vocabulary', 'diagnostic test', '...        33.0        139
# 4                               ['digital evidence']         5.0        128
#
#   page_end  ...    issue                            doi  \
# 0       S3  ...  8 Suppl  10.1016/j.bpobgyn.2014.10.013
# 1        +  ...      NaN   10.1007/978-3-642-27552-4_60
# 2      164  ...      NaN     10.1109/ICASSP.2001.940792
# 3      150  ...      NaN                            NaN
# 4      128  ...        4          10.1145/505248.505280
#
#                                                  pdf  \
# 0  //static.aminer.org/pdf/PDF/000/868/217/prefac...
# 1                                                NaN
# 2                                                NaN
# 3  //static.aminer.org/pdf/PDF/000/554/244/the_cl...
# 4  //static.aminer.org/pdf/PDF/000/776/363/digita...
#
#                                                  url  \
# 0  ['http://dx.doi.org/10.1016/j.bpobgyn.2014.10....
# 1  ['http://dx.doi.org/10.1007/978-3-642-27552-4_...
# 2  ['http://doi.ieeecomputersociety.org/10.1109/I...
# 3  ['http://psb.stanford.edu/psb-online/proceedin...
# 4       ['http://doi.acm.org/10.1145/505248.505280']
#
#                                             abstract       issn  \
# 0  On behalf of the IRPS 2010 Management Committe...  0275-004X
# 1  Augmented Reality is the technology that overl...  1867-5662
# 2   We investigate the fusion of audio and video ...        NaN
# 3  Existing medical vocabularies lack rich terms ...  2335-6936
# 4  The evolution of an information society is acc...        NaN
#
#                 isbn                                                fos  \
# 0  978-1-4244-5430-3    ['Computer science', 'Artificial intelligence']
# 1                NaN  ['Virtual image', 'Educational technology', 'C...
# 2                NaN  ['Weighting', 'Speech coding', 'Pattern recogn...
# 3                NaN  ['Ontology', 'RefSeq', 'Molecular diagnostics'...
# 4                NaN  ['Trusted Network Connect', 'Internet privacy'...
#
#                                           references  \
# 0  ['53e9b9adb7602d970459fe66', '53e9ba28b7602d97...
# 1  ['53e9a8c5b7602d9703216bc6', '53e9ab6fb7602d97...
# 2  ['53e9a863b7602d97031b24fe', '558aabb7e4b0b32f...
# 3  ['53e9a281b7602d9702b88181', '55a3f4c2612ca648...
# 4                                                NaN
#
#                                  topic
# 0                     -1_the_of_and_to
# 1             32_virtual_reality_vr_ar
# 2  11_speech_speaker_recognition_music
# 3  26_ontology_ontologies_semantic_web
# 4                     -1_the_of_and_to
#
# [5 rows x 22 columns]

# %%
data.drop(data[data['topic'] == '-1_the_of_and_to'].index, inplace=True)

# %%
data.reset_index(inplace=True)
data.to_csv('results/004_of_V13_topics.csv')
